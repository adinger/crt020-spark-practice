# %% [markdown]
# ### Window Functions

# %%
import sys
from pyspark.sql.window import Window
import pyspark.sql.functions as func
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Compute the Rank (skips numbers) for each product within its category based on the product's revenue

# %%
df = spark.read.option('header', True).csv('/FileStore/tables/productRevenue.csv')
display(spark.sql('select * from productRevenue').collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>category</th><th>revenue</th></tr></thead><tbody><tr><td>thin</td><td>cell phone</td><td>6000</td></tr><tr><td>normal</td><td>tablet</td><td>1500</td></tr><tr><td>mini</td><td>tablet</td><td>5500</td></tr><tr><td>ultra thin</td><td>cell phone</td><td>5000</td></tr><tr><td>very thin</td><td>cell phone</td><td>6000</td></tr><tr><td>big</td><td>tablet</td><td>2500</td></tr><tr><td>bendable</td><td>cell phone</td><td>3000</td></tr><tr><td>foldable</td><td>cell phone</td><td>3000</td></tr><tr><td>pro</td><td>tablet</td><td>4500</td></tr><tr><td>pro2</td><td>tablet</td><td>6500</td></tr></tbody></table></div>

# %%
windowSpec = Window.partitionBy(df['category']).orderBy(df['revenue'])
result = df.select(df['*'], func.rank().over(windowSpec).alias('rank_in_category'))
display(result.collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>category</th><th>revenue</th><th>rank_in_category</th></tr></thead><tbody><tr><td>normal</td><td>tablet</td><td>1500</td><td>1</td></tr><tr><td>big</td><td>tablet</td><td>2500</td><td>2</td></tr><tr><td>pro</td><td>tablet</td><td>4500</td><td>3</td></tr><tr><td>mini</td><td>tablet</td><td>5500</td><td>4</td></tr><tr><td>pro2</td><td>tablet</td><td>6500</td><td>5</td></tr><tr><td>bendable</td><td>cell phone</td><td>3000</td><td>1</td></tr><tr><td>foldable</td><td>cell phone</td><td>3000</td><td>1</td></tr><tr><td>ultra thin</td><td>cell phone</td><td>5000</td><td>3</td></tr><tr><td>thin</td><td>cell phone</td><td>6000</td><td>4</td></tr><tr><td>very thin</td><td>cell phone</td><td>6000</td><td>4</td></tr></tbody></table></div>

# %% [markdown]
# ##### Using Dense Rank (consecutive numbers)

# %%
result = df.select(df['*'], func.dense_rank().over(windowSpec).alias('dense_rank_in_category'))
display(result.collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>category</th><th>revenue</th><th>dense_rank_in_category</th></tr></thead><tbody><tr><td>normal</td><td>tablet</td><td>1500</td><td>1</td></tr><tr><td>big</td><td>tablet</td><td>2500</td><td>2</td></tr><tr><td>pro</td><td>tablet</td><td>4500</td><td>3</td></tr><tr><td>mini</td><td>tablet</td><td>5500</td><td>4</td></tr><tr><td>pro2</td><td>tablet</td><td>6500</td><td>5</td></tr><tr><td>bendable</td><td>cell phone</td><td>3000</td><td>1</td></tr><tr><td>foldable</td><td>cell phone</td><td>3000</td><td>1</td></tr><tr><td>ultra thin</td><td>cell phone</td><td>5000</td><td>2</td></tr><tr><td>thin</td><td>cell phone</td><td>6000</td><td>3</td></tr><tr><td>very thin</td><td>cell phone</td><td>6000</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# ##### In SQL

# %%
df.createOrReplaceTempView('productRevenue')
query = """SELECT *, 
  dense_rank() over (PARTITION BY category ORDER BY revenue) as dense_rank_in_category
  FROM productRevenue"""
display(spark.sql(query).collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>category</th><th>revenue</th><th>dense_rank_in_category</th></tr></thead><tbody><tr><td>normal</td><td>tablet</td><td>1500</td><td>1</td></tr><tr><td>big</td><td>tablet</td><td>2500</td><td>2</td></tr><tr><td>pro</td><td>tablet</td><td>4500</td><td>3</td></tr><tr><td>mini</td><td>tablet</td><td>5500</td><td>4</td></tr><tr><td>pro2</td><td>tablet</td><td>6500</td><td>5</td></tr><tr><td>bendable</td><td>cell phone</td><td>3000</td><td>1</td></tr><tr><td>foldable</td><td>cell phone</td><td>3000</td><td>1</td></tr><tr><td>ultra thin</td><td>cell phone</td><td>5000</td><td>2</td></tr><tr><td>thin</td><td>cell phone</td><td>6000</td><td>3</td></tr><tr><td>very thin</td><td>cell phone</td><td>6000</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# What are the best-selling and the second best-selling products in every category?

# %%
query = """SELECT
  rank,
  product,
  category,
  revenue
FROM (
  SELECT
    product,
    category,
    revenue,
    dense_rank() OVER (PARTITION BY category ORDER BY revenue DESC) as rank
  FROM productRevenue
  ) tmp
WHERE
  rank <= 2"""
display(spark.sql(query).collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rank</th><th>product</th><th>category</th><th>revenue</th></tr></thead><tbody><tr><td>1</td><td>pro2</td><td>tablet</td><td>6500</td></tr><tr><td>2</td><td>mini</td><td>tablet</td><td>5500</td></tr><tr><td>1</td><td>thin</td><td>cell phone</td><td>6000</td></tr><tr><td>1</td><td>very thin</td><td>cell phone</td><td>6000</td></tr><tr><td>2</td><td>ultra thin</td><td>cell phone</td><td>5000</td></tr></tbody></table></div>

# %% [markdown]
# What is the difference between the revenue of each product and the revenue of the best selling product in the same category as that product?

# %%
windowSpec = Window.partitionBy(df['category']).orderBy(df['revenue'].desc())
result = df.select(df['*'], func.max(df['revenue']).over(windowSpec).alias('max_revenue'), (func.max(df['revenue']).over(windowSpec) - df['revenue']).alias('revenue_diff'))
display(result.collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>category</th><th>revenue</th><th>max_revenue</th><th>revenue_diff</th></tr></thead><tbody><tr><td>pro2</td><td>tablet</td><td>6500</td><td>6500</td><td>0.0</td></tr><tr><td>mini</td><td>tablet</td><td>5500</td><td>6500</td><td>1000.0</td></tr><tr><td>pro</td><td>tablet</td><td>4500</td><td>6500</td><td>2000.0</td></tr><tr><td>big</td><td>tablet</td><td>2500</td><td>6500</td><td>4000.0</td></tr><tr><td>normal</td><td>tablet</td><td>1500</td><td>6500</td><td>5000.0</td></tr><tr><td>thin</td><td>cell phone</td><td>6000</td><td>6000</td><td>0.0</td></tr><tr><td>very thin</td><td>cell phone</td><td>6000</td><td>6000</td><td>0.0</td></tr><tr><td>ultra thin</td><td>cell phone</td><td>5000</td><td>6000</td><td>1000.0</td></tr><tr><td>bendable</td><td>cell phone</td><td>3000</td><td>6000</td><td>3000.0</td></tr><tr><td>foldable</td><td>cell phone</td><td>3000</td><td>6000</td><td>3000.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Defining Row and Range Windows

# %%
# Display original data
df = sqlContext.table('productRevenue')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>category</th><th>revenue</th></tr></thead><tbody><tr><td>thin</td><td>cell phone</td><td>6000</td></tr><tr><td>normal</td><td>tablet</td><td>1500</td></tr><tr><td>mini</td><td>tablet</td><td>5500</td></tr><tr><td>ultra thin</td><td>cell phone</td><td>5000</td></tr><tr><td>very thin</td><td>cell phone</td><td>6000</td></tr><tr><td>big</td><td>tablet</td><td>2500</td></tr><tr><td>bendable</td><td>cell phone</td><td>3000</td></tr><tr><td>foldable</td><td>cell phone</td><td>3000</td></tr><tr><td>pro</td><td>tablet</td><td>4500</td></tr><tr><td>pro2</td><td>tablet</td><td>6500</td></tr></tbody></table></div>

# %% [markdown]
# Row-Based Windows

# %%
windowSpec = Window.partitionBy(df.category).orderBy(df.revenue.desc()).rowsBetween(-1, 1)
result = df.select(df.category, df.product, df.revenue, func.avg(df.revenue).over(windowSpec).alias('running_avg'))
display(result.collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>product</th><th>revenue</th><th>running_avg</th></tr></thead><tbody><tr><td>tablet</td><td>pro2</td><td>6500</td><td>6000.0</td></tr><tr><td>tablet</td><td>mini</td><td>5500</td><td>5500.0</td></tr><tr><td>tablet</td><td>pro</td><td>4500</td><td>4166.666666666667</td></tr><tr><td>tablet</td><td>big</td><td>2500</td><td>2833.3333333333335</td></tr><tr><td>tablet</td><td>normal</td><td>1500</td><td>2000.0</td></tr><tr><td>cell phone</td><td>thin</td><td>6000</td><td>6000.0</td></tr><tr><td>cell phone</td><td>very thin</td><td>6000</td><td>5666.666666666667</td></tr><tr><td>cell phone</td><td>ultra thin</td><td>5000</td><td>4666.666666666667</td></tr><tr><td>cell phone</td><td>bendable</td><td>3000</td><td>3666.6666666666665</td></tr><tr><td>cell phone</td><td>foldable</td><td>3000</td><td>3000.0</td></tr></tbody></table></div>

# %% [markdown]
# Range-Based Windows

# %%
Window.unboundedPreceding
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: -9223372036854775808</div>

# %%
from pyspark.sql.types import IntegerType
windowSpec = Window.partitionBy(df.category).orderBy(df.revenue.desc()).rangeBetween(-1000000000000000000000, Window.unboundedFollowing)
newCol = func.avg(df['revenue']).over(windowSpec)
result = df.select(df.category, df.product, df.revenue, newCol.alias('avg_revenue'))
display(result.collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>product</th><th>revenue</th><th>avg_revenue</th></tr></thead><tbody><tr><td>tablet</td><td>pro2</td><td>6500</td><td>4100.0</td></tr><tr><td>tablet</td><td>mini</td><td>5500</td><td>4100.0</td></tr><tr><td>tablet</td><td>pro</td><td>4500</td><td>4100.0</td></tr><tr><td>tablet</td><td>big</td><td>2500</td><td>4100.0</td></tr><tr><td>tablet</td><td>normal</td><td>1500</td><td>4100.0</td></tr><tr><td>cell phone</td><td>thin</td><td>6000</td><td>4600.0</td></tr><tr><td>cell phone</td><td>very thin</td><td>6000</td><td>4600.0</td></tr><tr><td>cell phone</td><td>ultra thin</td><td>5000</td><td>4600.0</td></tr><tr><td>cell phone</td><td>bendable</td><td>3000</td><td>4600.0</td></tr><tr><td>cell phone</td><td>foldable</td><td>3000</td><td>4600.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Broadcast Variables and Accumulators

# %% [markdown]
# Accumulators

# %%
total_age = sc.accumulator(0)

def add_age(row):
  total_age.add(row.age)
  
df = spark.createDataFrame([(10,), (22,), (28,)], ['age'])
df.foreach(add_age) # gets printed to stdout of each executor, not driver
print('Total age = ',total_age.value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total age =  60
# </div>

# %% [markdown]
# Broadcast Variables

# %%
broadcastVar = sc.broadcast([1, 2, 3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
broadcastVar.value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: [1, 2, 3]</div>

# %% [markdown]
# ### RDD Transformations

# %% [markdown]
# Aggregate - a wide transformation

# %%
#aggregate(initial_val_per_partition, reducer_function, combiner_function)
l = [4,51,2,77,25,9]
inputRDD = sc.parallelize(l)
sumAndCount = inputRDD.aggregate((0,0), (lambda acc, elem: (acc[0] + elem, acc[1] + 1)), (lambda acc1, acc2: (acc1[0] + acc2[0], acc1[1] + acc2[1])))
print('Average = ', sumAndCount[0]/sumAndCount[1])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Average =  28.0
# </div>

# %%
# check
sum(l) / len(l)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 28.0</div>

# %% [markdown]
# ### Caching Data / Persistence Levels

# %%
from pyspark.sql.types import IntegerType
df = spark.createDataFrame(inputRDD, IntegerType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# default storage levels
# StorageLevel(useDisk, useMemory, useOffHeap, deserialized, replication=1)
help(df.storageLevel)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on StorageLevel in module pyspark.storagelevel object:
#
# class StorageLevel(builtins.object)
#   StorageLevel(useDisk, useMemory, useOffHeap, deserialized, replication=1)
#
#   Flags for controlling the storage of an RDD. Each StorageLevel records whether to use memory,
#   whether to drop the RDD to disk if it falls out of memory, whether to keep the data in memory
#   in a JAVA-specific serialized format, and whether to replicate the RDD partitions on multiple
#   nodes. Also contains static constants for some commonly used storage levels, MEMORY_ONLY.
#   Since the data is always serialized on the Python side, all the constants use the serialized
#   formats.
#
#   Methods defined here:
#
#   __init__(self, useDisk, useMemory, useOffHeap, deserialized, replication=1)
#       Initialize self.  See help(type(self)) for accurate signature.
#
#   __repr__(self)
#       Return repr(self).
#
#   __str__(self)
#       Return str(self).
#
#   ----------------------------------------------------------------------
#   Data descriptors defined here:
#
#   __dict__
#       dictionary for instance variables (if defined)
#
#   __weakref__
#       list of weak references to the object (if defined)
#
#   ----------------------------------------------------------------------
#   Data and other attributes defined here:
#
#   DISK_ONLY = StorageLevel(True, False, False, False, 1)
#
#   DISK_ONLY_2 = StorageLevel(True, False, False, False, 2)
#
#   MEMORY_AND_DISK = StorageLevel(True, True, False, False, 1)
#
#   MEMORY_AND_DISK_2 = StorageLevel(True, True, False, False, 2)
#
#   MEMORY_AND_DISK_SER = StorageLevel(True, True, False, False, 1)
#
#   MEMORY_AND_DISK_SER_2 = StorageLevel(True, True, False, False, 2)
#
#   MEMORY_ONLY = StorageLevel(False, True, False, False, 1)
#
#   MEMORY_ONLY_2 = StorageLevel(False, True, False, False, 2)
#
#   MEMORY_ONLY_SER = StorageLevel(False, True, False, False, 1)
#
#   MEMORY_ONLY_SER_2 = StorageLevel(False, True, False, False, 2)
#
#   OFF_HEAP = StorageLevel(True, True, True, False, 1)
#
# </div>

# %%
df2 = df.persist(StorageLevel.MEMORY_ONLY_SER_2)
print(df2.storageLevel)
df2.storageLevel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Memory Serialized 2x Replicated
# Out[74]: StorageLevel(False, True, False, False, 2)</div>

# %%
df.cache().storageLevel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: StorageLevel(True, True, False, True, 1)</div>

# %%
df.unpersist().storageLevel
