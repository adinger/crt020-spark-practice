# %% [markdown]
# ### SparkContext Configurations ###

# %%
# https://spark.apache.org/docs/latest/configuration.html#viewing-spark-properties

# %% [markdown]
# ### SparkSession ###

# %% [markdown]
# Create a DataFrame/Dataset from a collection (e.g. list or set)

# %%
from pyspark.sql import SparkSession

# create dataframe from list of dicts
spark = SparkSession.builder.appName("My Spark App").getOrCreate()
data = [{'name':'Alice','age':4}, {'name':'Bob','age':8}]
df = spark.createDataFrame(data, ['name','age'])
df.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/session.py:355: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn(&#34;inferring schema from dict is deprecated,&#34;
# Out[1]: [Row(name=4, age=&#39;Alice&#39;), Row(name=8, age=&#39;Bob&#39;)]</div>

# %%
# create dataframe from list of tuples
data = [('Alice',4), ('Bob',8)]
df = spark.createDataFrame(data, ['name','age'])
df.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [Row(name=&#39;Alice&#39;, age=4), Row(name=&#39;Bob&#39;, age=8)]</div>

# %%
# create dataframe from RDD and schema as Row object
from pyspark.sql import Row
data = [('Alice',4), ('Bob',8)]
rdd = sc.parallelize(data)
Person = Row('name', 'age')
person = rdd.map(lambda r: Person(*r))
df2 = spark.createDataFrame(person)
df2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [Row(name=&#39;Alice&#39;, age=4), Row(name=&#39;Bob&#39;, age=8)]</div>

# %% [markdown]
# Create a DataFrame for a range of numbers

# %%
df = spark.range(start=5, end=21, step=5, numPartitions=None)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Access the DataFrameReaders

# %%
spark.read.csv # also json, parquet, orc, jdbc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: &lt;bound method DataFrameReader.csv of &lt;pyspark.sql.readwriter.DataFrameReader object at 0x7f061752d390&gt;&gt;</div>

# %% [markdown]
# Register User Defined Functions (UDFs)

# %%
def sq(x):
  return x*x

spark.udf.register(name="sq", f=my_squared, returnType=IntegerType())
spark.range(5, 21, 5).registerTempTable("test")
spark.sql("SELECT id, sq(id) FROM test").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+
#  id|sq(id)|
# +---+------+
#   5|    25|
#  10|   100|
#  15|   225|
#  20|   400|
# +---+------+
#
# </div>

# %% [markdown]
# ### DataFrameReader ###

# %% [markdown]
# Read data for the “core” data formats (CSV, JSON, JDBC, ORC, Parquet, text and tables)

# %%
# read Json 3 ways
df = spark.read.json("/FileStore/tables/people.json")
df = spark.read.load(path="/FileStore/tables/people.json", format="json")
df = spark.read.format("json").load(path="/FileStore/tables/people.json")
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+
# age|  name|
# +---+------+
#  23|Angela|
#  10|   Bob|
#  44| Cathy|
#  39| Dylan|
#  56| Elena|
# +---+------+
#
# </div>

# %%
# read CSV
df3 = spark.read.option("header", True).option("inferSchema", True).csv("/FileStore/tables/people.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# read using JDBC
remote_table = spark.read.format("jdbc")\
  .option("driver", "org.postgresql.Driver")\
  .option("url", "jdbc:postgresql://database_server")\
  .option("dbtable", "schema.tablename")\
  .option("user", "me")\
  .option("password", "12345")\
  .load()

# read ORC
df5 = spark.read.orc("/path/to/file.orc")
# read Parquet
df6 = spark.read.parquet("/path/to/file.parquet")

# %% [markdown]
# How to configure options for specific formats

# %%
df = spark.read.option("header", True).option("inferSchema", True).csv("/FileStore/tables/people.csv")

# %% [markdown]
# How to read data from non-core formats using format() and load()

# %%
# format()
df = spark.read.format('json').load('/FileStore/tables/people.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# load()
df = spark.read.load(path='/FileStore/tables/people.json', format='json')
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+
# age|  name|
# +---+------+
#  23|Angela|
#  10|   Bob|
#  44| Cathy|
#  39| Dylan|
#  56| Elena|
# +---+------+
#
# </div>

# %% [markdown]
# How to specify a DDL-formatted schema

# %%
df = spark.read.csv(path='/FileStore/tables/people.csv', header=True, schema='NAME VARCHAR(255), AGE INTEGER')
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+---+
#   NAME|AGE|
# +------+---+
# Angela| 23|
#    Bob| 10|
#  Cathy| 44|
#  Dylan| 39|
#  Elena| 56|
# +------+---+
#
# </div>

# %% [markdown]
# How to construct and specify a schema using the StructType classes

# %%
from pyspark.sql.types import *
mySchema = StructType([StructField("name", StringType(), True), StructField("age", IntegerType(), True)])
df = spark.read.load(path='/FileStore/tables/people.json', format='json', schema=mySchema)
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 63</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     64</span>         <span class="ansi-green-fg">except</span> py4j<span class="ansi-blue-fg">.</span>protocol<span class="ansi-blue-fg">.</span>Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py</span> in <span class="ansi-cyan-fg">get_return_value</span><span class="ansi-blue-fg">(answer, gateway_client, target_id, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    327</span>                     <span class="ansi-blue-fg">&#34;An error occurred while calling {0}{1}{2}.\n&#34;</span><span class="ansi-blue-fg">.</span>
# <span class="ansi-green-fg">--&gt; 328</span><span class="ansi-red-fg">                     format(target_id, &#34;.&#34;, name), value)
# </span><span class="ansi-green-intense-fg ansi-bold">    329</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Py4JJavaError</span>: An error occurred while calling o3982.load.
# : org.apache.spark.sql.AnalysisException: Path does not exist: dbfs:/FileStore/tables/people.json;
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:614)
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:597)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike$class.flatMap(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.flatMap(List.scala:355)
# 	at org.apache.spark.sql.execution.datasources.DataSource.org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary(DataSource.scala:597)
# 	at org.apache.spark.sql.execution.datasources.DataSource.resolveRelation(DataSource.scala:391)
# 	at org.apache.spark.sql.DataFrameReader.loadV1Source(DataFrameReader.scala:307)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:293)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:214)
# 	at sun.reflect.GeneratedMethodAccessor477.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2248903751822491&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">.</span>types <span class="ansi-green-fg">import</span> <span class="ansi-blue-fg">*</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> mySchema <span class="ansi-blue-fg">=</span> StructType<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span>StructField<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;name&#34;</span><span class="ansi-blue-fg">,</span> StringType<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> StructField<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;age&#34;</span><span class="ansi-blue-fg">,</span> IntegerType<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>df <span class="ansi-blue-fg">=</span> spark<span class="ansi-blue-fg">.</span>read<span class="ansi-blue-fg">.</span>load<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;/FileStore/tables/people.json&#39;</span><span class="ansi-blue-fg">,</span> format<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;json&#39;</span><span class="ansi-blue-fg">,</span> schema<span class="ansi-blue-fg">=</span>mySchema<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> df<span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">load</span><span class="ansi-blue-fg">(self, path, format, schema, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    164</span>         self<span class="ansi-blue-fg">.</span>options<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">**</span>options<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    165</span>         <span class="ansi-green-fg">if</span> isinstance<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">,</span> basestring<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 166</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_df<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jreader<span class="ansi-blue-fg">.</span>load<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    167</span>         <span class="ansi-green-fg">elif</span> path <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    168</span>             <span class="ansi-green-fg">if</span> type<span class="ansi-blue-fg">(<

# %% [markdown]
# ### DataFrameWriter ###

# %% [markdown]
# Write data to the “core” data formats (csv, json, jdbc, orc, parquet, text and tables)

# %%
help(dbutils.fs.rm)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on method f_with_exception_handling in module dbutils:
#
# f_with_exception_handling(*args, **kwargs) method of dbutils.FSHandler instance
#
# </div>

# %%
df.write.parquet('/FileStore/tables/output/people.parquet', mode='Append')
df_written = spark.read.parquet('/FileStore/tables/output/people.parquet')
df_written.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+
# age|  name|
# +---+------+
#  23|Angela|
#  10|   Bob|
#  44| Cathy|
#  39| Dylan|
#  56| Elena|
#  23|Angela|
#  10|   Bob|
#  44| Cathy|
#  39| Dylan|
#  56| Elena|
# +---+------+
#
# </div>

# %% [markdown]
# Overwriting existing files

# %%
df.write.parquet('/FileStore/tables/output/people.parquet', mode='Overwrite')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# How to configure options for specific formats

# %%
df.write.options(header=True, sep='|').csv('/FileStore/tables/output/people.csv', mode='Overwrite')
df_written = spark.read.option('header', True).option('sep', '|').csv('/FileStore/tables/output/people.csv')
df_written.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+
# age|  name|
# +---+------+
#  23|Angela|
#  10|   Bob|
#  44| Cathy|
#  39| Dylan|
#  56| Elena|
# +---+------+
#
# </div>

# %% [markdown]
# How to write a data source to 1 single file or N separate files

# %%
df.coalesce(1).write.csv('/FileStore/tables/output/csv_1_partition/', mode='Overwrite')
df.repartition(5).write.csv('/FileStore/tables/output/csv_5_partitions/', mode='Overwrite')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables/output/csv_1_partition/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/output/csv_1_partition/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_1_partition/_committed_6041240411489043784</td><td>_committed_6041240411489043784</td><td>113</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_1_partition/_committed_8692727945481414173</td><td>_committed_8692727945481414173</td><td>212</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_1_partition/_started_6041240411489043784</td><td>_started_6041240411489043784</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_1_partition/_started_8692727945481414173</td><td>_started_8692727945481414173</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_1_partition/part-00000-tid-8692727945481414173-5bdeee7b-8825-4ff0-8c83-a22f45b6e657-321-1-c000.csv</td><td>part-00000-tid-8692727945481414173-5bdeee7b-8825-4ff0-8c83-a22f45b6e657-321-1-c000.csv</td><td>44</td></tr></tbody></table></div>

# %%
# %fs ls /FileStore/tables/output/csv_5_partitions/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/_committed_1336251933358378223</td><td>_committed_1336251933358378223</td><td>924</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/_committed_4894914513389392256</td><td>_committed_4894914513389392256</td><td>469</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/_started_1336251933358378223</td><td>_started_1336251933358378223</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/_started_4894914513389392256</td><td>_started_4894914513389392256</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/part-00000-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-323-1-c000.csv</td><td>part-00000-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-323-1-c000.csv</td><td>9</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/part-00001-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-324-1-c000.csv</td><td>part-00001-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-324-1-c000.csv</td><td>7</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/part-00002-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-325-1-c000.csv</td><td>part-00002-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-325-1-c000.csv</td><td>9</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/part-00003-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-326-1-c000.csv</td><td>part-00003-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-326-1-c000.csv</td><td>9</td></tr><tr><td>dbfs:/FileStore/tables/output/csv_5_partitions/part-00004-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-327-1-c000.csv</td><td>part-00004-tid-1336251933358378223-33fcc9c8-146d-4d9a-bbde-e938b769334f-327-1-c000.csv</td><td>10</td></tr></tbody></table></div>

# %%
df_out = spark.read.format('csv').load('/FileStore/tables/output/partitioned_csv/part-00001-tid-321870977250130119-fc361c0e-aad6-4a4b-ae42-d341000a1a02-271-1-c000.csv')
df_out.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+
# _c0|_c1|
# +---+---+
#  10|Bob|
# +---+---+
#
# </div>

# %% [markdown]
# How to write partitioned data

# %%
df.repartition(5).write.parquet('/FileStore/tables/output/partitioned/', mode='Overwrite')
display(dbutils.fs.ls('/FileStore/tables/output/partitioned/'))

# %% [markdown]
# How to bucket data by a given set of columns

# %%
# save as bucketed table file
# WARNING - cannot just do .bucketBy(...).save(path='/path/to/out/file') - MUST specify path in .option()
df.write.format('parquet')\
  .bucketBy(numBuckets=5, col='name')\
  .mode('overwrite')\
  .option('path', '/FileStore/tables/output/bucketed/')\
  .saveAsTable('sorted_bucketed_table')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables/output/bucketed/

# %%
# %sql SELECT * from sorted_bucketed_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>name</th></tr></thead><tbody><tr><td>56</td><td>Elena</td></tr><tr><td>39</td><td>Dylan</td></tr><tr><td>10</td><td>Bob</td></tr><tr><td>44</td><td>Cathy</td></tr><tr><td>23</td><td>Angela</td></tr></tbody></table></div>

# %%
# can save as just a table
df.write.format('parquet')\
  .bucketBy(numBuckets=5, col='name')\
  .mode('overwrite')\
  .saveAsTable('sorted_bucketed_table')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### DataFrame ###

# %% [markdown]
# Have a working understanding of every action such as take(), collect(), and foreach()

# %%
display(df.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>name</th></tr></thead><tbody><tr><td>23</td><td>Angela</td></tr><tr><td>10</td><td>Bob</td></tr><tr><td>44</td><td>Cathy</td></tr></tbody></table></div>

# %%
# foreach() - can be used to force-update an accumulator
total_age = sc.accumulator(0)

def print_row(row):
  total_age.add(row.age)
  
df.foreach(print_row) # gets printed to stdout of each executor, not driver
print(total_age.value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">172
# </div>

# %% [markdown]
# Produce a distinct set

# %%
df = sc.parallelize([2,2,4,1,1,4,6])
df.distinct().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [1, 2, 4, 6]</div>

# %% [markdown]
# Filtering data

# %%
df = spark.createDataFrame([('a',1), ('b',2), ('c',5), ('d',9), ('e',10)], ('letter', 'number'))
display(df.filter(df.number > 7).collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>letter</th><th>number</th></tr></thead><tbody><tr><td>d</td><td>9</td></tr><tr><td>e</td><td>10</td></tr></tbody></table></div>

# %% [markdown]
# Change number of partitions using repartition() and coalesce()

# %%
df2 = df.repartition(5)
df2.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 5</div>

# %%
df3 = df2.coalesce(2)
df3.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 2</div>

# %% [markdown]
# Joins

# %%
employees = spark.createDataFrame([('Ana', 'E1'), ('Bob', 'E2'), ('Charlie', 'E3')], ('Employee', 'EID'))
orders = spark.createDataFrame([('Order1', 'E1'), ('Order2', 'E2'), ('Order3', 'E3'), ('Order4', 'E1'), ('Order5', 'E2'), ('Order6', 'E2')], ('Order', 'EID'))
display(employees.join(orders, employees['EID'] == orders['EID']).select(collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee</th><th>EID</th><th>Order</th><th>EID</th></tr></thead><tbody><tr><td>Charlie</td><td>E3</td><td>Order3</td><td>E3</td></tr><tr><td>Ana</td><td>E1</td><td>Order1</td><td>E1</td></tr><tr><td>Ana</td><td>E1</td><td>Order4</td><td>E1</td></tr><tr><td>Bob</td><td>E2</td><td>Order2</td><td>E2</td></tr><tr><td>Bob</td><td>E2</td><td>Order5</td><td>E2</td></tr><tr><td>Bob</td><td>E2</td><td>Order6</td><td>E2</td></tr></tbody></table></div>

# %% [markdown]
# Unions

# %%
employees = spark.createDataFrame([('Ana', 'E1'), ('Bob', 'E2'), ('Charlie', 'E3')], ('Employee', 'EID'))
employees2 = spark.createDataFrame([('Dilbert', 'E8'), ('Egg', 'E11'), ('French', 'E8')], ('Employee', 'EID'))
display(employees.union(employees2).collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee</th><th>EID</th></tr></thead><tbody><tr><td>Ana</td><td>E1</td></tr><tr><td>Bob</td><td>E2</td></tr><tr><td>Charlie</td><td>E3</td></tr><tr><td>Dilbert</td><td>E8</td></tr><tr><td>Egg</td><td>E11</td></tr><tr><td>French</td><td>E8</td></tr></tbody></table></div>

# %% [markdown]
# Aggregates

# %%
df = spark.createDataFrame([('a',1), ('b',2), ('c',5), ('d',9), ('e',10)], ('letter', 'number'))
df.agg({'number':'max'}).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [Row(max(number)=10)]</div>

# %%
from pyspark.sql import functions
df.agg(functions.max('number')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: [Row(max(number)=10)]</div>

# %% [markdown]
# Converting a DataFrame to a global or temp view.

# %%
df.createTempView("myTempView")
df.createGlobalTempView("myGlobalTempView")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Applying broadcast hints

# %%
from pyspark.sql.functions import broadcast
employees = spark.createDataFrame([('Ana', 'E1'), ('Bob', 'E2'), ('Charlie', 'E3')], ('Employee', 'EID'))
orders = spark.createDataFrame([('Order1', 'E1'), ('Order2', 'E2'), ('Order3', 'E3'), ('Order4', 'E1'), ('Order5', 'E2'), ('Order6', 'E2')], ('Order', 'EID'))
broadcast(employees).join(orders, employees.EID == orders.EID).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---+------+---+
# Employee|EID| Order|EID|
# +--------+---+------+---+
#      Ana| E1|Order1| E1|
#      Bob| E2|Order2| E2|
#  Charlie| E3|Order3| E3|
#      Ana| E1|Order4| E1|
#      Bob| E2|Order5| E2|
#      Bob| E2|Order6| E2|
# +--------+---+------+---+
#
# </div>

# %%
# another way, using table views
employees.createOrReplaceTempView("employees")
orders.createOrReplaceTempView("orders")
broadcast(spark.table("employees")).join(spark.table("orders"), "EID").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------+------+
# EID|Employee| Order|
# +---+--------+------+
#  E1|     Ana|Order1|
#  E2|     Bob|Order2|
#  E3| Charlie|Order3|
#  E1|     Ana|Order4|
#  E2|     Bob|Order5|
#  E2|     Bob|Order6|
# +---+--------+------+
#
# </div>

# %% [markdown]
# ### Row & Column

# %% [markdown]
# Create a dataframe from Json

# %%
# create dataframe from json
from pyspark.sql.types import StructField, StringType, IntegerType, StructType 
schema = [StructField('name', StringType(), True), StructField('age', IntegerType(), True)]
schema_struct = StructType(fields=schema)
df = spark.read.json("/FileStore/tables/people.json", schema=schema_struct)
display(df.collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th></tr></thead><tbody><tr><td>Angela</td><td>23</td></tr><tr><td>Bob</td><td>10</td></tr><tr><td>Cathy</td><td>44</td></tr><tr><td>Dylan</td><td>39</td></tr><tr><td>Elena</td><td>56</td></tr></tbody></table></div>

# %% [markdown]
# Compute and add a new column

# %%
df_new = df.withColumn('doubleage',df['age']*2)
df_new.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+---+---------+
#   name|age|doubleage|
# +------+---+---------+
# Angela| 23|       46|
#    Bob| 10|       20|
#  Cathy| 44|       88|
#  Dylan| 39|       78|
#  Elena| 56|      112|
# +------+---+---------+
#
# </div>

# %% [markdown]
# Rename a column

# %%
df_new.withColumnRenamed('doubleage', 'double_age').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+---+----------+
#   name|age|double_age|
# +------+---+----------+
# Angela| 23|        46|
#    Bob| 10|        20|
#  Cathy| 44|        88|
#  Dylan| 39|        78|
#  Elena| 56|       112|
# +------+---+----------+
#
# </div>

# %% [markdown]
# Drop a column

# %%
df_new.drop('double_age').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+---+---------+
#   name|age|doubleage|
# +------+---+---------+
# Angela| 23|       46|
#    Bob| 10|       20|
#  Cathy| 44|       88|
#  Dylan| 39|       78|
#  Elena| 56|      112|
# +------+---+---------+
#
# </div>

# %% [markdown]
# Select row based on condition

# %%
result = df.filter(df.age > 40).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Turn row into dictionary

# %%
row = result[0]
row
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: Row(name=&#39;Cathy&#39;, age=44)</div>

# %%
row.asDict('name')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: {&#39;name&#39;: &#39;Cathy&#39;, &#39;age&#39;: 44}</div>

# %%
row.asDict().keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: dict_keys([&#39;name&#39;, &#39;age&#39;])</div>

# %%
row.asDict().values()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: dict_values([&#39;Cathy&#39;, 44])</div>

# %% [markdown]
# ### Spark SQL Functions

# %% [markdown]
# Aggregate functions: getting the first or last item from an array

# %%
# example 1: select from array
from pyspark.sql.functions import element_at
df = spark.createDataFrame([(["a", "b", "c"],), ([],)], ['col1'])
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
#      col1|
# +---------+
# [a, b, c]|
#        []|
# +---------+
#
# </div>

# %%
# get first element
df.select(element_at(df.col1, 1)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
# element_at(col1, 1)|
# +-------------------+
#                   a|
#                null|
# +-------------------+
#
# </div>

# %%
# get last element
df.select(element_at(df.col1, -1)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
# element_at(col1, -1)|
# +--------------------+
#                    c|
#                 null|
# +--------------------+
#
# </div>

# %%
# example 2: select from map
df = spark.createDataFrame([({"a":1, "b":2},), ({"b":3, "d":4},)], ["col1"])
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------+
#             col1|
# +----------------+
# [a -&gt; 1, b -&gt; 2]|
# [d -&gt; 4, b -&gt; 3]|
# +----------------+
#
# </div>

# %%
# lookup element using key
result = df.select(element_at(df.col1, "b").alias("b_value"))
result.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+
# b_value|
# +-------+
#       2|
#       3|
# +-------+
#
# </div>

# %%
# example 3: split an array element
from pyspark.sql import Row
row = [Row(col1="a", col2="b", col3=["c", "d"])]
rdd = sc.parallelize(row)
df = spark.createDataFrame(rdd)
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+------+
# col1|col2|  col3|
# +----+----+------+
#    a|   b|[c, d]|
# +----+----+------+
#
# </div>

# %%
# split column 3 into two separate columns
result = df.withColumn("col4", df["col3"].getItem(1))\
           .withColumn("col3", df["col3"].getItem(0))
result.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+----+----+
# col1|col2|col3|col4|
# +----+----+----+----+
#    a|   b|   c|   d|
# +----+----+----+----+
#
# </div>

# %% [markdown]
# Aggregate functions: computing the min and max values of a column

# %%
from pyspark.sql import functions as F
df = spark.createDataFrame([(10,), (2,), (7,)], ["nums"])
df.select(F.min(df.nums), F.max(df.nums)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+
# min(nums)|max(nums)|
# +---------+---------+
#         2|       10|
# +---------+---------+
#
# </div>

# %% [markdown]
# Collection functions: testing if an array contains a value

# %%
df.select(df.nums, array_contains(df.nums, 2).alias("has_2")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
#      nums|has_2|
# +---------+-----+
# [1, 2, 3]| true|
# [2, 3, 6]| true|
#    [4, 6]|false|
# +---------+-----+
#
# </div>

# %% [markdown]
# Collection functions: exploding or flattening data

# %%
from pyspark.sql import Row
from pyspark.sql.functions import explode
df = spark.createDataFrame([Row(mylist=[1,2,3]), Row(mylist=[4,5,6])])
df.select(explode(df.mylist)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [Row(col=1), Row(col=2), Row(col=3), Row(col=4), Row(col=5), Row(col=6)]</div>

# %%
df = spark.createDataFrame([([[1, 2, 3], [4, 5], [6]],), ([None, [4, 5]],)], ['data'])
display(df.collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>data</th></tr></thead><tbody><tr><td>List(List(1, 2, 3), List(4, 5), List(6))</td></tr><tr><td>List(null, List(4, 5))</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import flatten
df.select(flatten(df.data)).show()  # null element in array results in null flattened result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#      flatten(data)|
# +------------------+
# [1, 2, 3, 4, 5, 6]|
#               null|
# +------------------+
#
# </div>

# %%
# instead of null element in array, use empty array
df = spark.createDataFrame([([[1, 2, 3], [4, 5], [6]],), ([[None], [4, 5]],)], ['data'])
df.select(flatten(df.data)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#      flatten(data)|
# +------------------+
# [1, 2, 3, 4, 5, 6]|
#           [, 4, 5]|
# +------------------+
#
# </div>

# %% [markdown]
# Date time functions: parsing strings into timestamps or formatting timestamps into strings

# %%
from pyspark.sql.functions import from_unixtime

# convert from epoch milliseconds to string representation
spark.conf.set("spark.sql.session.timeZone", "America/Los_Angeles")
time_df = spark.createDataFrame([(1428476400,)], ['unix_time'])
time_df.select(from_unixtime('unix_time').alias('ts')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: [Row(ts=&#39;2015-04-08 00:00:00&#39;)]</div>

# %%
# convert from string representation to time object in specified timezone
from pyspark.sql.functions import from_utc_timestamp
df = spark.createDataFrame([('1997-02-28 10:30:00', 'JST')], ['timestamp', 'timezone'])
df.select(from_utc_timestamp(df.timestamp, df.timezone).alias('local_time')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: [Row(local_time=datetime.datetime(1997, 2, 28, 19, 30))]</div>

# %%
# convert from string representation of local time to time object in utc time
from pyspark.sql.functions import to_utc_timestamp
df = spark.createDataFrame([('1997-02-28 10:30:00', 'JST')], ['ts', 'tz'])
df.select(to_utc_timestamp(df.ts, df.tz).alias('utc_time')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: [Row(utc_time=datetime.datetime(1997, 2, 28, 1, 30))]</div>

# %%
# convert from string representation to time object by specifying format of string
from pyspark.sql.functions import to_date
df = spark.createDataFrame([('1997-02-28 10:30:00',)], ['timestamp'])
df.select(to_date(df.timestamp, 'yyyy-MM-dd HH:mm:ss').alias('date')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: [Row(date=datetime.date(1997, 2, 28))]</div>

# %% [markdown]
# Math functions: computing the cosine, floor or log of a number

# %%
from pyspark.sql.functions import cos, floor, log
df = spark.createDataFrame([(3,), (6,)], ["data"])
df.select(cos(df.data).alias("cosine"), floor(df.data).alias("floor"), log(10.0, df.data).alias("log10")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-----+-------------------+
#              cosine|floor|              log10|
# +-------------------+-----+-------------------+
# -0.9899924966004454|    3|0.47712125471966244|
#  0.9601702866503661|    6| 0.7781512503836435|
# +-------------------+-----+-------------------+
#
# </div>

# %% [markdown]
# Misc functions: converting a value to crc32, md5, sha1 or sha2

# %%
from pyspark.sql.functions import crc32, md5, sha1, sha2

spark.createDataFrame([('abcdef',)], ['data']).select(crc32('data'), md5('data'), sha1('data'), sha2('data', numBits=256)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+--------------------+--------------------+--------------------+
# crc32(data)|           md5(data)|          sha1(data)|     sha2(data, 256)|
# +-----------+--------------------+--------------------+--------------------+
#  1267612143|e80b5017098950fc5...|1f8ac10f23c5b5bc1...|bef57ec7f53a6d40b...|
# +-----------+--------------------+--------------------+--------------------+
#
# </div>

# %% [markdown]
# Test if a column is null or not-null, NAN

# %%
from pyspark.sql import Row
df = spark.createDataFrame([Row(name='Alice', age=10), Row(name='Bob', age=11), Row(name='Charlie', age=None)])
df.filter(df.age.isNull()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+
#  age|   name|
# +----+-------+
# null|Charlie|
# +----+-------+
#
# </div>

# %%
from pyspark.sql.functions import isnull
df.select(isnull(df.age)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# (age IS NULL)|
# +-------------+
#         false|
#         false|
#          true|
# +-------------+
#
# </div>

# %%
df.filter(df.age.isNotNull()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----+
# age| name|
# +---+-----+
#  10|Alice|
#  11|  Bob|
# +---+-----+
#
# </div>

# %% [markdown]
# Sorting functions: sorting data in descending order, ascending order, and sorting with proper null handling

# %%
df = spark.createDataFrame([Row(name='Alice', age=10), Row(name='Bob', age=11), Row(name='Charlie', age=None)])
df.sort(df.age.asc()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+
#  age|   name|
# +----+-------+
# null|Charlie|
#   10|  Alice|
#   11|    Bob|
# +----+-------+
#
# </div>

# %%
df.sort(df.age.desc_nulls_last()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+
#  age|   name|
# +----+-------+
#   11|    Bob|
#   10|  Alice|
# null|Charlie|
# +----+-------+
#
# </div>

# %% [markdown]
# UDF functions: employing a UDF function.

# %%
from pyspark.sql.types import IntegerType

str_len_udf = udf(lambda str: len(str), IntegerType())
df = spark.createDataFrame([Row(name='Alice', age=10), Row(name='Bob', age=11), Row(name='Charlie', age=None)])
df.select(df.name, str_len_udf(df.name).alias('name_length')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------+
#    name|name_length|
# +-------+-----------+
#   Alice|          5|
#     Bob|          3|
# Charlie|          7|
# +-------+-----------+
#
# </div>

# %%
# same thing with SQL
df.createOrReplaceTempView("people")
spark.udf.register("str_len_udf", lambda str: len(str))
spark.sql("SELECT name, str_len_udf(name) FROM people").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+
#    name|str_len_udf(name)|
# +-------+-----------------+
#   Alice|                5|
#     Bob|                3|
# Charlie|                7|
# +-------+-----------------+
#
# </div>

# %% [markdown]
# String functions: applying a provided regular expression

# %%
df = spark.createDataFrame([("Alice", 1), ("Bob", 2), ("Charlie",  3)], ["name", "age"])
regex = 'ice$'
df.filter(df.name.rlike(regex)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [Row(name=&#39;Alice&#39;, age=1)]</div>

# %%
# select a column based on regex for column name
df = spark.createDataFrame([("a", 1), ("b", 2), ("c",  3)], ["Col1", "Col2"])
df.select(df.colRegex("`(Col1)?+.+`")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+
# Col2|
# +----+
#    1|
#    2|
#    3|
# +----+
#
# </div>

# %% [markdown]
# String functions: trimming strings

# %%
from pyspark.sql.functions import rtrim
df = spark.createDataFrame([("       Alice", 1), ("Bob        ", 2), ("    Charlie",  3)], ["name", "age"])
df.select(rtrim(df.name)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: [Row(rtrim(name)=&#39;       Alice&#39;),
#  Row(rtrim(name)=&#39;Bob&#39;),
#  Row(rtrim(name)=&#39;    Charlie&#39;)]</div>

# %%
from pyspark.sql.functions import ltrim
df = spark.createDataFrame([("       Alice", 1), ("Bob        ", 2), ("    Charlie",  3)], ["name", "age"])
df.select(ltrim(df.name)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: [Row(ltrim(name)=&#39;Alice&#39;),
#  Row(ltrim(name)=&#39;Bob        &#39;),
#  Row(ltrim(name)=&#39;Charlie&#39;)]</div>

# %% [markdown]
# String functions: extracting substrings

# %%
df = spark.createDataFrame([("Alice", 1), ("Bob", 2), ("Charlie",  3)], ["name", "age"])
df.select(df.name.substr(0,3)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [Row(substring(name, 0, 3)=&#39;Ali&#39;),
#  Row(substring(name, 0, 3)=&#39;Bob&#39;),
#  Row(substring(name, 0, 3)=&#39;Cha&#39;)]</div>
